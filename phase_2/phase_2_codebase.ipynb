# %% [markdown]
# ### The modules we will need

# %%
# We import the SQLite python module for the database handling
import sqlite3

# the bz2 module is used to uncompress the files
import bz2

# the csv module serves for manipulating csv files
import csv

# while the OS module will help us manage the filepaths
import os

# pandas will be useful for storing and processing query results
import pandas as pd

# %% [markdown]
# ### We uncompress the bz2 file

# %%
# The current working directory
cwd = os.getcwd()

# compressed file name
compressed = '2008.csv.bz2'

# The filepath of the compressed file
filepath_to_compressed = cwd + '/' + 'input' + '/' + compressed

# %%
# We first check whether the csv file already exists, if so we pass
# If not, we open the file, uncompress it and then write a new csv file.

if os.path.isfile(filepath_to_compressed[:-4]):    # isfile returns True if the filepath_to_compressed[:-4] leads to a file
    print ('File already exists')

else:
    zipfile = bz2.BZ2File(filepath_to_compressed)    # open the file
    data = zipfile.read()    # get the decompressed data. Pay attention, it is in binary format
    newfilepath = filepath[:-4]    # cut away the .bz2 ending
    open(newfilepath, 'wb').write(data)    # tranform the uncompressed binary data into a csv file.
    
    print('File' + filepath + 'created')
# Out:
# File already exists

# %% [markdown]
# ### Now that we have all the relevant data we can start building our database

# %%
# We first create the database and the tables inside it


## The relevant filepaths
database_name = 'air_flights_project.db'
filepath_to_database = cwd + '/' + 'output' + '/' + database_name

creation_script_name = 'database_creation_script'
filepath_to_creation_script = cwd + '/' + 'output' + '/' + creation_script_name


## We transform our file into a long string, to be fed to sqlite
creation_string = ''
with open(filepath_to_creation_script,'r') as creation_script:
    for line in creation_script:
        creation_string += line


## creation of the database 
conn = sqlite3.connect(filepath_to_database)  # connect if exists, otherwise create database
cursor = conn.cursor()
cursor.executescript(creation_string)  # The script will create tables only if they do not exist -IF NOT EXIST clause

conn.close()

# %% [markdown]
# ### Now we can insert the data into the various tables

# %%
# TABLE 1
# CARRIERS


# 1 - The relevant filepaths

# recall that filepath_to_database = cwd + '/' + 'output' + '/' + database_name
filepath_to_carriers = cwd + '/' + 'input' + '/' + 'carriers.csv'



# 2 - open the connection and clear the contents of the table
conn = sqlite3.connect(filepath_to_database)
cursor = conn.cursor()
query = ''' delete from carriers  '''
cursor.execute(query)

# 3 - read the lines 
with open(filepath_to_carriers,'r') as carriers:
    carriers_reader = csv.reader(carriers,delimiter=",")
    next(carriers_reader)  # skip first line with column names using the reader's next method
    
    for line in carriers_reader:

        query = ''' insert into carriers (Code, Full_name ) values (?, ?) '''
        cursor.execute(query, [line[0], line[1]])



conn.commit()



query =  ''' select * from carriers'''

carriers_df = pd.read_sql_query(query, conn, index_col=None, coerce_float=False, parse_dates=None, chunksize=None)

conn.close()

# %%
carriers_df
# Out:
#         Code                                     Full_name
# 0        02Q                                 Titan Airways
# 1        04Q                            Tradewind Aviation
# 2        05Q                           Comlux Aviation, AG
# 3        06Q                 Master Top Linhas Aereas Ltd.
# 4        07Q                           Flair Airlines Ltd.
# 5        09Q                                Swift Air, LLC
# 6        0BQ                                           DCA
# 7        0CQ                          ACM AIR CHARTER GmbH
# 8        0FQ          Maine Aviation Aircraft Charter, LLC
# 9        0GQ  Inter Island Airways, d/b/a Inter Island Air
# 10       0HQ       Polar Airlines de Mexico d/b/a Nova Air
# 11        0J                                    JetClub AG
# 12       0JQ                               Vision Airlines
# 13       0KQ                Mokulele Flight Services, Inc.
# 14       0LQ                             Metropix UK, LLP.
# 15       0MQ         Multi-Aero, Inc. d/b/a Air Choice One
# 16        0Q                           Flying Service N.V.
# 17        16                             PSA Airlines Inc.
# 18        17                             Piedmont Airlines
# 19        1I                       Sky Trek Int'l Airlines
# 20        2E                           Smokey Bay Air Inc.
# 21        2F                       Frontier Flying Service
# 22        2M                       Midway Express Airlines
# 23        2O                            Island Air Service
# 24        2R                                     Regal Air
# 25        2T                     Canada 3000 Airlines Ltd.
# 26        2U                       Valley Air Express Inc.
# 27        37                                      Zeal 320
# 28        3C                             Regions Air, Inc.
# 29        3F                         Pacific Airways, Inc.
# ...      ...                                           ...
# 1461      YB                    Trans Continental Airlines
# 1462     YBQ                               Yellow Bird Air
# 1463      YM                           Royal West Airlines
# 1464      YR    Scenic Airlines Inc. d/b/a Scenic Airlines
# 1465      YV                            Mesa Airlines Inc.
# 1466      YX                         Midwest Airline, Inc.
# 1467      Z3                                   PM Air, LLC
# 1468  Z3 (1)                                       Promech
# 1469      ZA                            Accessair Holdings
# 1470     ZAQ                          Zas Airline Of Egypt
# 1471      ZB                              Monarch Airlines
# 1472      ZE                          Lineas Aereas Azteca
# 1473     ZFZ                     Mcphillips Flying Service
# 1474     ZIA                                Air New Mexico
# 1475      ZK                          Great Lakes Airlines
# 1476     ZKQ                          Zantop International
# 1477      ZL                                     Affretair
# 1478     ZMZ                   Winnipesaukee Aviation Inc.
# 1479      ZN                             Key Airlines Inc.
# 1480      ZO                          Florida Express Inc.
# 1481      ZP                                Air St. Thomas
# 1482      ZQ                        Caribbean Sun Airlines
# 1483      ZS                            Hispaniola Airways
# 1484     ZUQ                           Zuliana De Aviacion
# 1485      ZV                              Air Midwest Inc.
# 1486      ZW                   Air Wisconsin Airlines Corp
# 1487      ZX                                  Air Georgian
# 1488  ZX (1)                                    Airbc Ltd.
# 1489      ZY                        Atlantic Gulf Airlines
# 1490     ZYZ                          Skyway Aviation Inc.
#
# [1491 rows x 2 columns]

# %% [markdown]
# ### A simpe test to verify that all the data  has been loaded

# %%
def count_csv_rows(filepath):
    '''
    a simple way to count the lines in a csv
    '''
    with open(filepath) as csv_file:
        return ( sum(1 for line in csv_file) )

# %%
def count_database_rows(filepath, table_name):
    '''
    a simple way to count the rows in a table
    '''
    conn = sqlite3.connect(filepath)
    cursor = conn.cursor()
    query = '''select count(*) from ''' + table_name
    cursor.execute(query)
    return ( cursor.fetchall()[0][0] )

# %%
# the lines in the source csv should be one greater than the rows in the database table
count_csv_rows ( filepath_to_carriers ) == 1 + count_database_rows ( filepath_to_database, 'carriers' )
# Out:
# True

# %%
# TABLE 2
# PLANES


# 1 - The relevant filepaths
# recall that filepath_to_database = cwd + '/' + 'output' + '/' + database_name
filepath_to_planes = cwd + '/' + 'input' + '/' + 'plane-data.csv'



# 2 - open the connection and clear the contents of the table
conn = sqlite3.connect(filepath_to_database)
cursor = conn.cursor()
query = ''' delete from planes  '''
cursor.execute(query)



# 3 - read the lines and insert them into the database
with open(filepath_to_planes,'r') as planes:
    planes_reader = csv.reader(planes,delimiter=",")
    next(planes_reader)  # skip first line with column names using the reader's next method
    
    for line in planes_reader:
        
        
        if len(line) == 9:  # checking if all fields are present in the csv. There are many rows with only a TailNum
            
           
        
            # The last column in the csv contains four different kinds of values
            # 'None', valid date strings - '1969', technically valid but inappropriate date string - '0000', and empty fields
            # we try to capture various cases and transform them accordingly
            type_none = (lambda x: None if ( (x == 'None') or  (x == '0000') or (x == 0)) else int(x)) 

            # For Issue-date we need a little manipulation to get to this date format YYYY-MM-DD, which sqlite understands
            date_manipulation = (lambda x: None if (x == 'None') else ( x[6:10] + '-' + x[0:2] + '-' + x[3:5]) )
            
            
            query = ''' insert into planes 
                ( TailNum, Type,  Manufacturer, Issue_date,  Model,Status,Aircraft_type ,Engine_type ,  Plane_year ) 
                values (?,?,?,?,?,?,?,?,?) '''
            
            
            
            cursor.execute(query, [line[0],
                                   line[1],
                                   line[2],
                                  date_manipulation(line[3] ),
                                   line[4],
                                   line[5],
                                   line[6],
                                   line[7],
                                   type_none(line[8]) ] )
        
        else:  # In case there is only a TailNum in the csv, we need to fill in the gaps with None types
            for element in line:
                element = element.strip('\r\n').strip('"')
                

            query = ''' insert into planes 
                ( TailNum, Type,  Manufacturer, Issue_date,  Model,Status,Aircraft_type ,Engine_type ,  Plane_year ) 
                values (?,?,?,?,?,?,?,?,?) '''
            
            cursor.execute(query, [element,None,None,None,None,None,None,None,None ] )

conn.commit()



query =  ''' select * from planes'''

planes_df = pd.read_sql_query(query, conn, index_col=None, coerce_float=False, parse_dates=None, chunksize=None)

conn.close()

# %%
# pandas automatically casts integers into float in the presence of NaNs
# For this reason Plane_year is integer in the database table, and becomes float in the dataframe

planes_df
# Out:
#      TailNum                 Type                   Manufacturer  Issue_date  \
# 0     N050AA                 None                           None        None
# 1     N051AA                 None                           None        None
# 2     N052AA                 None                           None        None
# 3     N054AA                 None                           None        None
# 4     N055AA                 None                           None        None
# 5     N056AA                 None                           None        None
# 6     N057AA                 None                           None        None
# 7     N058AA                 None                           None        None
# 8     N059AA                 None                           None        None
# 9     N060AA                 None                           None        None
# 10    N061AA                 None                           None        None
# 11    N062AA                 None                           None        None
# 12    N063AA                 None                           None        None
# 13    N064AA                 None                           None        None
# 14    N065AA                 None                           None        None
# 15    N066AA                 None                           None        None
# 16    N067AA                 None                           None        None
# 17    N068AA                 None                           None        None
# 18    N069AA                 None                           None        None
# 19    N070AA                 None                           None        None
# 20    N071AA                 None                           None        None
# 21    N072AA                 None                           None        None
# 22    N073AA                 None                           None        None
# 23    N074AA                 None                           None        None
# 24    N075AA                 None                           None        None
# 25    N076AA                 None                           None        None
# 26    N077AA                 None                           None        None
# 27    N078AA                 None                           None        None
# 28    N079AA                 None                           None        None
# 29    N080AA                 None                           None        None
# ...      ...                  ...                            ...         ...
# 4999  N988AT          Corporation                         BOEING  2002-05-15
# 5000  N988CA          Corporation                       CANADAIR  2008-02-01
# 5001  N988DL          Corporation  MCDONNELL DOUGLAS AIRCRAFT CO  1991-11-20
# 5002  N988HA          Corporation                    DEHAVILLAND  2008-05-15
# 5003  N989AT          Corporation                         BOEING  2002-06-03
# 5004  N989CA          Corporation                       CANADAIR  2007-08-14
# 5005  N989DL          Corporation  MCDONNELL DOUGLAS AIRCRAFT CO  1991-12-20
# 5006  N989HA          Corporation                    DEHAVILLAND  2008-05-15
# 5007  N990AT          Corporation                         BOEING  2002-07-16
# 5008  N990DL          Corporation  MCDONNELL DOUGLAS AIRCRAFT CO  1991-12-20
# 5009  N991AT          Corporation                         BOEING  2002-08-29
# 5010  N991cA          Corporation                       CANADAIR  2007-08-30
# 5011  N991DL          Corporation  MCDONNELL DOUGLAS AIRCRAFT CO  1992-01-06
# 5012  N991HA          Corporation                    DEHAVILLAND  2008-05-15
# 5013  N992AT          Corporation                         BOEING  2002-09-12
# 5014  N992DL          Corporation  MCDONNELL DOUGLAS AIRCRAFT CO  1992-01-10
# 5015  N993AT          Corporation                         BOEING  2002-07-23
# 5016  N993DL          Corporation  MCDONNELL DOUGLAS AIRCRAFT CO  1992-02-07
# 5017  N994AT          Corporation                         BOEING  2002-11-05
# 5018  N994DL          Corporation  MCDONNELL DOUGLAS CORPORATION  1992-02-03
# 5019  N995AT          Corporation                         BOEING  2002-11-08
# 5020  N995DL          Corporation  MCDONNELL DOUGLAS AIRCRAFT CO  1992-03-06
# 5021  N996AT          Corporation                         BOEING  2002-07-30
# 5022  N996DL          Corporation  MCDONNELL DOUGLAS AIRCRAFT CO  1992-02-27
# 5023  N997AT          Corporation                         BOEING  2003-01-02
# 5024  N997DL          Corporation  MCDONNELL DOUGLAS AIRCRAFT CO  1992-03-11
# 5025  N998AT          Corporation                         BOEING  2003-01-23
# 5026  N998DL          Corporation  MCDONNELL DOUGLAS CORPORATION  1992-04-02
# 5027  N999CA  Foreign Corporation                       CANADAIR  2008-07-09
# 5028  N999DN          Corporation  MCDONNELL DOUGLAS CORPORATION  1992-04-02
#
#             Model Status            Aircraft_type Engine_type  Plane_year
# 0            None   None                     None        None         NaN
# 1            None   None                     None        None         NaN
# 2            None   None                     None        None         NaN
# 3            None   None                     None        None         NaN
# 4            None   None                     None        None         NaN
# 5            None   None                     None        None         NaN
# 6            None   None                     None        None         NaN
# 7            None   None                     None        None         NaN
# 8            None   None                     None        None         NaN
# 9            None   None                     None        None         NaN
# 10           None   None                     None        None         NaN
# 11           None   None                     None        None         NaN
# 12           None   None                     None        None         NaN
# 13           None   None                     None        None         NaN
# 14           None   None                     None        None         NaN
# 15           None   None                     None        None         NaN
# 16           None   None                     None        None         NaN
# 17           None   None                     None        None         NaN
# 18           None   None                     None        None         NaN
# 19           None   None                     None        None         NaN
# 20           None   None                     None        None         NaN
# 21           None   None                     None        None         NaN
# 22           None   None                     None        None         NaN
# 23           None   None                     None        None         NaN
# 24           None   None                     None        None         NaN
# 25           None   None                     None        None         NaN
# 26           None   None                     None        None         NaN
# 27           None   None                     None        None         NaN
# 28           None   None                     None        None         NaN
# 29           None   None                     None        None         NaN
# ...           ...    ...                      ...         ...         ...
# 4999      717-200  Valid  Fixed Wing Multi-Engine   Turbo-Fan      2001.0
# 5000  CL-600-2B19  Valid  Fixed Wing Multi-Engine   Turbo-Jet      1997.0
# 5001        MD-88  Valid  Fixed Wing Multi-Engine   Turbo-Fan      1991.0
# 5002    DHC-8-202  Valid  Fixed Wing Multi-Engine  Turbo-Prop      1996.0
# 5003      717-200  Valid  Fixed Wing Multi-Engine   Turbo-Fan      2001.0
# 5004  CL-600-2B19  Valid  Fixed Wing Multi-Engine   Turbo-Jet      1998.0
# 5005        MD-88  Valid  Fixed Wing Multi-Engine   Turbo-Fan      1991.0
# 5006    DHC-8-202  Valid  Fixed Wing Multi-Engine  Turbo-Prop      1996.0
# 5007      717-200  Valid  Fixed Wing Multi-Engine   Turbo-Fan      2001.0
# 5008        MD-88  Valid  Fixed Wing Multi-Engine   Turbo-Fan      1991.0
# 5009      717-200  Valid  Fixed Wing Multi-Engine   Turbo-Fan         NaN
# 5010  CL-600-2B19  Valid  Fixed Wing Multi-Engine   Turbo-Jet      1998.0
# 5011        MD-88  Valid  Fixed Wing Multi-Engine   Turbo-Fan      1991.0
# 5012    DHC-8-202  Valid  Fixed Wing Multi-Engine  Turbo-Prop      1996.0
# 5013      717-200  Valid  Fixed Wing Multi-Engine   Turbo-Fan      2002.0
# 5014        MD-88  Valid  Fixed Wing Multi-Engine   Turbo-Fan      1991.0
# 5015      717-200  Valid  Fixed Wing Multi-Engine   Turbo-Fan      2002.0
# 5016        MD-88  Valid  Fixed Wing Multi-Engine   Turbo-Fan      1991.0
# 5017      717-200  Valid  Fixed Wing Multi-Engine   Turbo-Fan      2002.0
# 5018        MD-88  Valid  Fixed Wing Multi-Engine   Turbo-Jet      1991.0
# 5019      717-200  Valid  Fixed Wing Multi-Engine   Turbo-Fan      2002.0
# 5020        MD-88  Valid  Fixed Wing Multi-Engine   Turbo-Fan      1991.0
# 5021      717-200  Valid  Fixed Wing Multi-Engine   Turbo-Fan      2002.0
# 5022        MD-88  Valid  Fixed Wing Multi-Engine   Turbo-Fan      1991.0
# 5023      717-200  Valid  Fixed Wing Multi-Engine   Turbo-Fan      2002.0
# 5024        MD-88  Valid  Fixed Wing Multi-Engine   Turbo-Fan      1992.0
# 5025      717-200  Valid  Fixed Wing Multi-Engine   Turbo-Fan      2002.0
# 5026        MD-88  Valid  Fixed Wing Multi-Engine   Turbo-Jet      1992.0
# 5027  CL-600-2B19  Valid  Fixed Wing Multi-Engine   Turbo-Jet      1998.0
# 5028        MD-88  Valid  Fixed Wing Multi-Engine   Turbo-Jet      1992.0
#
# [5029 rows x 9 columns]

# %%
# the lines in the source csv should be one greater than the rows in the database table
count_csv_rows ( filepath_to_planes ) == 1 + count_database_rows ( filepath_to_database, 'planes' )
# Out:
# True

# %%
# TABLE 3
# AIRPORTS


# 1 - The relevant filepaths
# recall that filepath_to_database = cwd + '/' + 'output' + '/' + database_name
filepath_to_airports = cwd + '/' + 'input' + '/' + 'airports.csv'


# 2 - open the connection and clear the contents of the table
conn = sqlite3.connect( filepath_to_database )
cursor = conn.cursor()
query = ''' delete from airports  '''
cursor.execute(query)


# 3 - read the lines and insert them into the database
with open(filepath_to_airports,'r') as airports:
    airports_reader = csv.reader(airports,delimiter=",")
    next(airports_reader)  # skip first line with column names using the reader's next method
    
    for line in airports_reader:
        
        if len(line) == 7:  # checking if all fields are present in the csv

            query = ''' insert into airports ( IATA,Airport_name,City,
            US_State,Country,Latitude,Longitude ) values (?,?,?,?,?,?,?) '''
            
            cursor.execute(query, [line[0],line[1],line[2],line[3],line[4],float(line[5]),float(line[6]) ] )
        else:
            print(line) # Get us informed if a line has missing fields

conn.commit()


query =  ''' select * from airports'''

airports_df = pd.read_sql_query(query, conn, index_col=None, coerce_float=False, parse_dates=None, chunksize=None)

conn.close()

# %%
airports_df
# Out:
#      IATA                  Airport_name                City US_State  \
# 0     00M                      Thigpen          Bay Springs       MS
# 1     00R          Livingston Municipal          Livingston       TX
# 2     00V                   Meadow Lake    Colorado Springs       CO
# 3     01G                  Perry-Warsaw               Perry       NY
# 4     01J              Hilliard Airpark            Hilliard       FL
# 5     01M             Tishomingo County             Belmont       MS
# 6     02A                   Gragg-Wade              Clanton       AL
# 7     02C                       Capitol          Brookfield       WI
# 8     02G             Columbiana County      East Liverpool       OH
# 9     03D              Memphis Memorial             Memphis       MO
# 10    04M                Calhoun County           Pittsboro       MS
# 11    04Y              Hawley Municipal              Hawley       MN
# 12    05C        Griffith-Merrillville             Griffith       IN
# 13    05F      Gatesville - City/County          Gatesville       TX
# 14    05U                        Eureka              Eureka       NV
# 15    06A              Moton  Municipal            Tuskegee       AL
# 16    06C                    Schaumburg  Chicago/Schaumburg       IL
# 17    06D               Rolla Municipal               Rolla       ND
# 18    06M              Eupora Municipal              Eupora       MS
# 19    06N                      Randall           Middletown       NY
# 20    06U               Jackpot/Hayden              Jackpot       NV
# 21    07C                 Dekalb County              Auburn       IN
# 22    07F          Gladewater Municipal          Gladewater       TX
# 23    07G                 Fitch H Beach           Charlotte       MI
# 24    07K        Central City Municipal        Central City       NE
# 25    08A            Wetumpka Municipal            Wetumpka       AL
# 26    08D             Stanley Municipal             Stanley       ND
# 27    08K                 Harvard State             Harvard       NE
# 28    08M         Carthage-Leake County            Carthage       MS
# 29    09A         Butler-Choctaw County              Butler       AL
# ...   ...                           ...                 ...      ...
# 3346  Y55             Crandon Municipal             Crandon       WI
# 3347  Y63          Elbow Lake Municipal          Elbow Lake       MN
# 3348  Y66               Drummond Island     Drummond Island       MI
# 3349  Y68               Tracy Municipal               Tracy       MN
# 3350  Y70                  Ionia County               Ionia       MI
# 3351  Y74                      Hankins             Parshall       ND
# 3352  Y83                 Sandusky City            Sandusky       MI
# 3353  Y93             Atlanta Municipal             Atlanta       MI
# 3354  YAK                       Yakutat             Yakutat       AK
# 3355  YAP             Yap International                  NA       NA
# 3356  YIP                    Willow Run             Detroit       MI
# 3357  YKM           Yakima Air Terminal              Yakima       WA
# 3358  YKN         Chan Gurney Municipal             Yankton       SD
# 3359  YNG    Youngstown-Warren Regional          Youngstown       OH
# 3360  YUM  Yuma MCAS-Yuma International                Yuma       AZ
# 3361  Z08                           Ofu         Ofu Village       AS
# 3362  Z09                      Kasigluk            Kasigluk       AK
# 3363  Z13                      Akiachak            Akiachak       AK
# 3364  Z17                         Ophir               Ophir       AK
# 3365  Z40                     Goose Bay           Goose Bay       AK
# 3366  Z55                   Lake Louise         Lake Louise       AK
# 3367  Z73                 Nelson Lagoon       Nelson Lagoon       AK
# 3368  Z84                         Clear        Clear A.F.B.       AK
# 3369  Z91                   Birch Creek         Birch Creek       AK
# 3370  Z95                       Cibecue             Cibecue       AZ
# 3371  ZEF               Elkin Municipal               Elkin       NC
# 3372  ZER     Schuylkill Cty/Joe Zerbey          Pottsville       PA
# 3373  ZPH         Zephyrhills Municipal         Zephyrhills       FL
# 3374  ZUN                    Black Rock                Zuni       NM
# 3375  ZZV          Zanesville Municipal          Zanesville       OH
#
#                              Country   Latitude   Longitude
# 0                                USA  31.953765  -89.234505
# 1                                USA  30.685861  -95.017928
# 2                                USA  38.945749 -104.569893
# 3                                USA  42.741347  -78.052081
# 4                                USA  30.688012  -81.905944
# 5                                USA  34.491667  -88.201111
# 6                                USA  32.850487  -86.611453
# 7                                USA  43.087510  -88.177869
# 8                                USA  40.673313  -80.641406
# 9                                USA  40.447259  -92.226961
# 10                               USA  33.930112  -89.342852
# 11                               USA  46.883849  -96.350899
# 12                               USA  41.519619  -87.401093
# 13                               USA  31.421276  -97.796968
# 14                               USA  39.604167 -116.005060
# 15                               USA  32.460472  -85.680036
# 16                               USA  41.989341  -88.101243
# 17                               USA  48.884341  -99.620877
# 18                               USA  33.534566  -89.312569
# 19                               USA  41.431566  -74.391917
# 20                               USA  41.976022 -114.658091
# 21                               USA  41.307167  -85.064333
# 22                               USA  32.528839  -94.971746
# 23                               USA  42.574509  -84.811431
# 24                               USA  41.116681  -98.050336
# 25                               USA  32.529439  -86.328221
# 26                               USA  48.300799 -102.406351
# 27                               USA  40.651385  -98.079787
# 28                               USA  32.761246  -89.530071
# 29                               USA  32.119313  -88.127462
# ...                              ...        ...         ...
# 3346                             USA  45.516630  -88.933447
# 3347                             USA  45.986071  -95.991999
# 3348                             USA  46.009311  -83.743934
# 3349                             USA  44.249957  -95.604454
# 3350                             USA  42.937700  -85.060667
# 3351                             USA  47.936401 -102.142114
# 3352                             USA  43.454187  -82.849380
# 3353                             USA  45.000008  -84.133337
# 3354                             USA  59.503361 -139.660226
# 3355  Federated States of Micronesia   9.516700  138.100000
# 3356                             USA  42.237927  -83.530409
# 3357                             USA  46.568170 -120.544059
# 3358                             USA  42.916694  -97.385944
# 3359                             USA  41.260736  -80.679097
# 3360                             USA  32.656583 -114.605972
# 3361                             USA  14.184351 -169.670024
# 3362                             USA  60.872022 -162.524809
# 3363                             USA  60.904532 -161.420910
# 3364                             USA  63.146037 -156.529865
# 3365                             USA  61.394451 -149.845556
# 3366                             USA  62.293689 -146.579422
# 3367                             USA  56.007536 -161.160367
# 3368                             USA  64.301204 -149.120144
# 3369                             USA  66.273996 -145.824038
# 3370                             USA  34.003333 -110.444167
# 3371                             USA  36.280024  -80.786069
# 3372                             USA  40.706449  -76.373147
# 3373                             USA  28.228065  -82.155916
# 3374                             USA  35.083227 -108.791777
# 3375                             USA  39.944458  -81.892105
#
# [3376 rows x 7 columns]

# %%
# the lines in the source csv should be one greater than the rows in the database table
count_csv_rows ( filepath_to_airports ) == 1 + count_database_rows ( filepath_to_database, 'airports' )
# Out:
# True

# %%
# TABLE 4
# Flights

# 1 - The relevant filepaths
# recall that filepath_to_database = cwd + '/' + 'output' + '/' + database_name
filepath_to_flights = cwd + '/' + 'input' + '/' + '2008.csv'


# 2 - open the connection and clear the contents of the table
conn = sqlite3.connect(filepath_to_database)
cursor = conn.cursor()
query = ''' delete from flights  '''
cursor.execute(query)


# 3 - read the lines and insert them into the database
with open(filepath_to_flights,'r') as flights:
    flights_reader = csv.reader(flights,delimiter=",")
    next(flights_reader)  # skip first line with column names using the reader's, next method
    
    for line in flights_reader:
  
        
        if len(line) == 29:  # checking if all fields are present in the csv


            query = ''' insert into flights (FlightYear,FlightMonth,FlightDay,DayOfWeek,DepTime,CRSDepTime,
            ArrTime,CRSArrTime,UniqueCarrier,FlightNum,TailNum,ActualElapsedTime,
            CRSElapsedTime,AirTime,ArrDelay,DepDelay,Origin,Dest,Distance,TaxiIn,
            TaxiOut,Cancelled,CancellationCode,Diverted,CarrierDelay,WeatherDelay,
            NASDelay,SecurityDelay,LateAircraftDelay ) 
            values (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?) '''
            
            my_none = (lambda x: None if ((x == 'NA') or (x == '') ) else int(x))  # We replace None-string with 0 else we cast the string into integer

            string_none = (lambda x: None if ((x == 'NA') or (x == '') or (x == 'Unknown') ) else (x))  # We replace NA or empty string with Python None
            
            #The 'railroad' here aims at putting together all the pieces of a string that SQLite can treat as timestamp
            my_timestamp = (lambda x, y, z, w: None if ((w == 'NA') or (w == '') ) else
                    (x + '-' + y.rjust(2,'0') + '-' + z.rjust(2,'0') + ' ' + w[:-2].rjust(2,'0') + ':' + w[-2:] ) ) 
            
            # we wrap the query into a try clause. Any row that might create a problem will be sent to the except part
            try:
                cursor.execute(query, [my_none(line[0]),   # FlightYear
                                       my_none(line[1]),   # FlightMonth
                                       my_none(line[2]),   # FlightDay
                                       my_none(line[3]),   # DayOfWeek
                                       my_timestamp(line[0],line[1],line[2],line[4]),   # DepTime
                                       my_timestamp(line[0],line[1],line[2],line[5]),   # CRSDepTime
                                       my_timestamp(line[0],line[1],line[2],line[6]),   # ArrTime
                                       my_timestamp(line[0],line[1],line[2],line[7]),   # CRSArrTime
                                       (line[8]),          # UniqueCarrier
                                       my_none(line[9]),   # FlightNum
                                       string_none(line[10]),         # TailNum
                                       my_none(line[11]),  # ActualElapsedTime
                                       my_none(line[12]),  # CRSElapsedTime
                                       my_none(line[13]),  # AirTime
                                       my_none(line[14]),  # ArrDelay
                                       my_none(line[15]),  # DepDelay
                                       (line[16]),         # Origin
                                       (line[17]),         # Dest
                                       my_none(line[18]),  # Distance
                                       my_none(line[19]),  # TaxiIn
                                       my_none(line[20]),  # TaxiOut
                                       (line[21]),         # Cancelled
                                       string_none(line[22]),  # CancellationCode
                                       (line[23]),         # Diverted
                                       my_none(line[24]),  # CarrierDelay
                                       my_none(line[25]),  # WeatherDelay
                                       my_none(line[26]),  # NASDelay
                                       my_none(line[27]),  # SecurityDelay
                                       my_none(line[28])]) # LateAircraftDelay
            except:  # The main error was caused by four duplicate lines that violated the uniqueness constraint
                print (line)  # Let us see the troublesome lines
     
        else:
            print(line) # Get us informed if a line has missing fields



conn.commit()



query =  ''' select * from flights limit 200'''

flights_df = pd.read_sql_query(query, conn, index_col=None, coerce_float=False, parse_dates=None, chunksize=None)

conn.close()
# Out:
# ['2008', '2', '28', '4', '829', '835', '1341', '1350', 'F9', '728', 'N201FR', '192', '195', '172', '-9', '-6', 'DEN', 'DCA', '1476', '6', '14', '0', '', '0', 'NA', 'NA', 'NA', 'NA', 'NA']
# 
# 12         829  ...    9.0     12.0          0              None         0
# 13        1016  ...    7.0     21.0          0              None         0
# 14        1827  ...    4.0     10.0          0              None         0
# 15        2272  ...    6.0      9.0          0              None         0
# 16         675  ...    7.0      8.0          0              None         0
# 17        1144  ...    5.0     16.0          0              None         0
# 18           4  ...    4.0      9.0          0              None         0
# 19          54  ...    2.0      5.0          0              None         0
# 20          68  ...    3.0      7.0          0              None         0
# 21         623  ...    5.0      5.0          0              None         0
# 22         717  ...    2.0      5.0          0              None         0
# 23        1244  ...    2.0      5.0          0              None         0
# 24        2101  ...    3.0      5.0          0              None         0
# 25        2553  ...    2.0      7.0          0              None         0
# 26         188  ...    6.0      6.0          0              None         0
# 27        1754  ...    3.0      7.0          0              None         0
# 28        2275  ...    5.0     13.0          0              None         0
# 29         550  ...    2.0      8.0          0              None         0
# ..         ...  ...    ...      ...        ...               ...       ...
# 170       2025  ...    8.0     13.0          0              None         0
# 171       2450  ...    8.0     11.0          0              None         0
# 172       2794  ...    7.0      7.0          0              None         0
# 173       3232  ...    6.0     10.0          0              None         0
# 174        767  ...    4.0      9.0          0              None         0
# 175        762  ...    3.0     18.0          0              None         0
# 176       3327  ...    4.0     12.0          0              None         0
# 177        125  ...    4.0     12.0          0              None         0
# 178        126  ...    NaN      NaN          1                 A         0
# 179        127  ...    4.0     13.0          0              None         0
# 180        223  ...    5.0      9.0          0              None         0
# 181        237  ...    3.0     15.0          0              None         0
# 182        280  ...    4.0     18.0          0              None         0
# 183        864  ...    3.0     19.0          0              None         0
# 184        900  ...    4.0     10.0          0              None         0
# 185        962  ...   28.0      8.0          0              None         0
# 186       1011  ...    4.0     12.0          0              None         0
# 187       1258  ...    3.0     17.0          0              None         0
# 188       1950  ...    5.0     10.0          0              None         0
# 189       3135  ...    3.0     10.0          0              None         0
# 190       3233  ...    4.0     11.0          0              None         0
# 191         86  ...    4.0     24.0          0              None         0
# 192        479  ...    3.0      9.0          0              None         0
# 193        875  ...    2.0     10.0          0              None         0
# 194       2111  ...    4.0     14.0          0              None         0
# 195        187  ...    4.0     26.0          0              None         0
# 196        725  ...    4.0      8.0          0              None         0
# 197        731  ...    4.0      8.0          0              None         0
# 198        872  ...    6.0     16.0          0              None         0
# 199        906  ...    3.0     11.0          0              None         0
#
#      CarrierDelay WeatherDelay NASDelay  SecurityDelay  LateAircraftDelay
# 0             NaN          NaN      NaN            NaN                NaN
# 1             NaN          NaN      NaN            NaN                NaN
# 2             NaN          NaN      NaN            NaN                NaN
# 3             NaN          NaN      NaN            NaN                NaN
# 4             2.0          0.0      0.0            0.0               32.0
# 5             NaN          NaN      NaN            NaN                NaN
# 6            10.0          0.0      0.0            0.0               47.0
# 7             NaN          NaN      NaN            NaN                NaN
# 8             NaN          NaN      NaN            NaN                NaN
# 9             NaN          NaN      NaN            NaN                NaN
# 10            NaN          NaN      NaN            NaN                NaN
# 11            8.0          0.0      0.0            0.0               72.0
# 12            NaN          NaN      NaN            NaN                NaN
# 13            NaN          NaN      NaN            NaN                NaN
# 14            NaN          NaN      NaN            NaN                NaN
# 15            NaN          NaN      NaN            NaN                NaN
# 16            3.0          0.0      0.0            0.0               12.0
# 17            NaN          NaN      NaN            NaN                NaN
# 18            0.0          0.0      0.0            0.0               16.0
# 19           12.0          0.0      0.0            0.0               25.0
# 20            NaN          NaN      NaN            NaN                NaN
# 21            7.0          0.0      0.0            0.0               12.0
# 22            NaN          NaN      NaN            NaN                NaN
# 23            NaN          NaN      NaN            NaN                NaN
# 24            NaN          NaN      NaN            NaN                NaN
# 25            NaN          NaN      NaN            NaN                NaN
# 26           40.0          0.0      0.0            0.0                7.0
# 27            NaN          NaN      NaN            NaN                NaN
# 28            NaN          NaN      NaN            NaN                NaN
# 29            NaN          NaN      NaN            NaN                NaN
# ..            ...          ...      ...            ...                ...
# 170           4.0          0.0      0.0            0.0               22.0
# 171          13.0          0.0      0.0            0.0               64.0
# 172          60.0          0.0      0.0            0.0               12.0
# 173           4.0          0.0      0.0            0.0               18.0
# 174           NaN          NaN      NaN            NaN                NaN
# 175           NaN          NaN      NaN            NaN                NaN
# 176           3.0          0.0      0.0            0.0               22.0
# 177           NaN          NaN      NaN            NaN                NaN
# 178           NaN          NaN      NaN            NaN                NaN
# 179           NaN          NaN      NaN            NaN                NaN
# 180          21.0          0.0      0.0            0.0               94.0
# 181           2.0          0.0      0.0            0.0               38.0
# 182          14.0          0.0     10.0            0.0               29.0
# 183           NaN          NaN      NaN            NaN                NaN
# 184          11.0          0.0      2.0            0.0               40.0
# 185          45.0          0.0     23.0            0.0               25.0
# 186           NaN          NaN      NaN            NaN                NaN
# 187           NaN          NaN      NaN            NaN                NaN
# 188           NaN          NaN      NaN            NaN                NaN
# 189          15.0          0.0      4.0            0.0                0.0
# 190           NaN          NaN      NaN            NaN                NaN
# 191           NaN          NaN      NaN            NaN                NaN
# 192          38.0          0.0      0.0            0.0               26.0
# 193          32.0          0.0      0.0            0.0               39.0
# 194           NaN          NaN      NaN            NaN                NaN
# 195           0.0          0.0     16.0            0.0                0.0
# 196           3.0          0.0      0.0            0.0               18.0
# 197           NaN          NaN      NaN            NaN                NaN
# 198           NaN          NaN      NaN            NaN                NaN
# 199          27.0          0.0      0.0            0.0                0.0
#
# [200 rows x 29 columns]

# %%
# The lines in the source csv should be 5 greater than the rows in the database table.
# 1 for the header and 4 for the duplicate lines
count_csv_rows ( filepath_to_flights ) == 5 + count_database_rows ( filepath_to_database, 'flights' )
# Out:
# True

# %% [markdown]
# ### After having inserted all the data, we should build custom indexes

# %%
# Indexes
# We will need them for the flights table, that is big and complicated.
# We have choosen the columns that are unique enough to be useful, and relevant to our possible queries

conn = sqlite3.connect(filepath_to_database)
cursor = conn.cursor()

query = '''

CREATE INDEX idx_flights_FlightDay ON flights ( FlightDay );

CREATE INDEX idx_flights_UniqueCarrier ON flights ( UniqueCarrier );

CREATE INDEX idx_flights_FlightNum ON flights ( FlightNum );

CREATE INDEX idx_flights_TailNum ON flights ( TailNum );

CREATE INDEX idx_flights_Origin ON flights ( Origin );

CREATE INDEX idx_flights_Dest ON flights ( Dest );


'''

cursor.executescript(query)

conn.commit()

conn.close()
